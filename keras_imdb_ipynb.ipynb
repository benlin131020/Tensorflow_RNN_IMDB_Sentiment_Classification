# %%
import urllib.request
import os
import tarfile

# %%
url="http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
filepath="data/aclImdb_v1.tar.gz"
if not os.path.isfile(filepath):
    result=urllib.request.urlretrieve(url,filepath)
    print('downloaded:',result)

# %%
if not os.path.exists("data/aclImdb"):
    tfile = tarfile.open("data/aclImdb_v1.tar.gz", 'r:gz')
    result=tfile.extractall('data/')

# %% [markdown]
# # 1. Import Library

# %%
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
# Out:
# C:\Users\Meng-Han\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # 資料準備

# %% [markdown]
# # 讀取檔案

# %%
import re
def rm_tags(text):
    re_tag = re.compile(r'<[^>]+>')
    return re_tag.sub('', text)

# %%
import os
def read_files(filetype):
    path = "data/aclImdb/"
    file_list=[]

    positive_path=path + filetype+"/pos/"
    for f in os.listdir(positive_path):
        file_list+=[positive_path+f]
    
    negative_path=path + filetype+"/neg/"
    for f in os.listdir(negative_path):
        file_list+=[negative_path+f]
        
    print('read',filetype, 'files:',len(file_list))
       
    all_labels = ([1] * 12500 + [0] * 12500) 
    
    all_texts  = []
    for fi in file_list:
        with open(fi,encoding='utf8') as file_input:
            all_texts += [rm_tags(" ".join(file_input.readlines()))]
            
    return all_labels,all_texts

# %%
y_train,train_text=read_files("train")
# Out:
# read train files: 25000

# %%
y_test,test_text=read_files("test")
# Out:
# read test files: 25000

# %% [markdown]
# # 查看正面評價的影評

# %%
train_text[0]
# Out:
# 'Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as "Teachers". My 35 years in the teaching profession lead me to believe that Bromwell High\'s satire is much closer to reality than is "Teachers". The scramble to survive financially, the insightful students who can see right through their pathetic teachers\' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line: INSPECTOR: I\'m here to sack one of your teachers. STUDENT: Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn\'t!'

# %%
y_train[0]
# Out:
# 1

# %% [markdown]
# # 查看負面評價的影評

# %%
train_text[12499]
# Out:
# 'Working-class romantic drama from director Martin Ritt is as unbelievable as they come, yet there are moments of pleasure due mostly to the charisma of stars Jane Fonda and Robert De Niro (both terrific). She\'s a widow who can\'t move on, he\'s illiterate and a closet-inventor--you can probably guess the rest. Adaptation of Pat Barker\'s novel "Union Street" (a better title!) is so laid-back it verges on bland, and the film\'s editing is a mess, but it\'s still pleasant; a rosy-hued blue-collar fantasy. There are no overtures to serious issues (even the illiteracy angle is just a plot-tool for the ensuing love story) and no real fireworks, though the characters are intentionally a bit colorless and the leads are toned down to an interesting degree. The finale is pure fluff--and cynics will find it difficult to swallow--though these two characters deserve a happy ending and the picture wouldn\'t really be satisfying any other way. *** from ****'

# %%
y_train[12499]
# Out:
# 1

# %% [markdown]
# # 先讀取所有文章建立字典，限制字典的數量為nb_words=2000

# %%
token = Tokenizer(num_words=2000)
token.fit_on_texts(train_text)

# %% [markdown]
# # Tokenizer屬性

# %% [markdown]
# # fit_on_texts 讀取多少文章

# %%
print(token.document_count)
# Out:
# 25000

# %%
print(token.word_index)
# Out:
# {'dictioary': 86047, 'lecter': 20081, "split'": 63532, 'swimmer': 19859, 'morrer': 63560, 'alternations': 59236, 'filmaan': 67759, "f14's": 48578, 'act': 507, 'kieslowski': 52799, 'ishmael': 34143, 'stadium': 7433, 'jordanthink': 67097, 'acquires': 26722, 'status': 2668, 'hollywoodize': 78353, 'splattered': 16520, 'summerlee': 71171, 'jacqualine': 73301, 'michinoku': 44529, 'jasmine': 19195, '40th': 31583, 'run': 518, "'golden": 31244, 'sous': 51730, 'meryl': 5090, 'charlene': 37978, "own'": 43488, 'expressionbad': 50340, 'archaeologists': 24033, "manufacturer's": 79662, 'ahahhahahaha': 84366, 'schlonged': 80388, "'84'": 85230, "guy''": 57683, 'leaps\x85': 62013, 'dice': 12123, 'viscously': 42715, 'noisier': 51300, 'solved': 8146, 'nelson': 3246, 'marvelled': 63383, 'kitley': 79015, "sacker's": 86606, 'ragnardocks': 84792, "payback's": 75375, 'mothballed': 50607, "caulfield's": 71495, 'hairs': 16524, 'tomlinson': 10742, 'denouement': 7223, 'woolly': 71144, 'hittite': 58893, 'gnome': 34418, 'palm': 7599, "pterdactyl's": 80074, 'submarines': 24311, "'bazza'": 36171, "castro's": 28408, 'koma': 83051, 'ruinously': 53832, 'gapers': 52310, "demon'": 64271, "yourself'": 43464, 'gemmell': 89333, 'magicbecause': 79769, 'beat': 1555, 'jeckyll': 85076, 'millar': 20612, "blackie's": 45523, 'weened': 58834, 'boulevards': 44663, 'brightly': 12768, 'clatter': 88994, 'programmation': 81603, 'blasphemous': 16703, "inarritu's": 39223, 'spider': 5050, 'flack': 24444, 'promisingly': 17012, 'simpatico': 63861, 'viewers': 794, "stalker's": 49067, 'afore': 18023, 'skims': 36537, 'dismembered': 18925, 'stynwyck': 45874, 'hiroshi': 47748, 'insanely': 9554, 'bloodletting': 20883, 'anticipation': 5524, 'booking': 41296, 'there\x85': 87212, 'quit': 4955, 'delores': 24305, 'birds': 3800, 'interrupted': 7644, 'spindles': 68321, 'mississippi': 19881, 'suggestion': 5962, 'conversational': 24384, 'coffinand': 68492, 'rodnunsky': 82943, 'whinnying': 87975, 'geometrically': 52948, 'copy': 1034, 'tripped': 21073, "''thunderball": 61390, 'aficionado': 20220, 'clyton': 86608, "america'": 52600, 'inconclusive': 25748, 'catalogued': 51926, 'clayface': 38828, 'dina': 50119, 'squeeing': 67343, 'unloading': 36424, 'littlekuriboh': 83637, 'babel': 21584, 'mindblowing': 41683, "'speedy": 51910, 'mollify': 57996, 'addition': 1574, 'scrutiny': 13684, 'spiraling': 20160, 'gait': 33549, 'escher': 33203, 'oblique': 26096, 'accidentally': 2509, 'occupies': 16988, 'lata': 24600, 'dorfmann': 81442, 'inveigh': 61524, 'warhols': 8587, 'larder': 58280, 'reconfirmed': 68834, 'blodwyn': 53347, 'justly': 15654, 'infelicities': 62615, 'appetit': 49235, 'gucci': 39648, 'deighton': 36475, 'sparks': 7432, 'nomm': 68827, 'gabriele': 17459, 'aissa': 60504, 'medications': 30317, 'enthuses': 60099, 'clarification': 38141, '10overall': 34319, 'heartwrenching': 31113, 'plex': 29973, 'brand': 3425, 'ukwell': 70567, 'dispatcher': 50770, 'rhyes': 58939, 'bookending': 54038, 'sherriff': 38197, 'cooking': 6927, "'tigerland'": 37410, 'alcoholism': 8787, 'algerians': 52403, "gannon's": 17548, "hutch's": 63543, 'rival': 2995, 'cloys': 77941, 'seminars': 35261, 'carload': 84201, 'greetings': 14095, 'concerto': 35553, 'thither': 74786, 'hooted': 74077, 'clambake': 82031, 'describing': 6048, "3po's": 87507, 'wrinkler': 88091, "atlantic'": 39882, 'door»': 70809, 'rowlands': 7252, 'moro': 66680, 'anorak': 46921, 'apart': 967, 'oriented': 5931, 'abides': 67115, 'assistance': 7935, 'bernard': 5345, 'collection': 1591, 'frenetically': 35317, 'telepathically': 29097, 'diy': 28619, 'motorola': 52771, 'punishment': 4982, 'rescuer': 41603, 'stationed': 19223, 'rhee': 88904, 'vagina': 14051, 'unbanned': 58597, 'googling': 44470, 'net': 5763, 'segall': 72307, 'hoofer': 29603, 'donlevy': 24450, 'lucy': 3103, 'setna': 58609, 'eggert': 23300, 'belles': 32808, 'eek': 51130, 'outsider': 10448, 'hearen': 88512, 'captured': 1992, 'reproductive': 29825, 'breasted': 17131, 'quinns': 61472, "dollars'": 47361, 'lavigne': 46668 ...

# %% [markdown]
# # 將每一篇文章的文字轉換一連串的數字
# # 只有在字典中的文字會轉換為數字

# %%
x_train_seq = token.texts_to_sequences(train_text)
x_test_seq  = token.texts_to_sequences(test_text)

# %%
print(train_text[0])
# Out:
# Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as "Teachers". My 35 years in the teaching profession lead me to believe that Bromwell High's satire is much closer to reality than is "Teachers". The scramble to survive financially, the insightful students who can see right through their pathetic teachers' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line: INSPECTOR: I'm here to sack one of your teachers. STUDENT: Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn't!

# %%
print(x_train_seq[0])
# Out:
# [308, 6, 3, 1068, 208, 8, 29, 1, 168, 54, 13, 45, 81, 40, 391, 109, 137, 13, 57, 149, 7, 1, 481, 68, 5, 260, 11, 6, 72, 5, 631, 70, 6, 1, 5, 1, 1530, 33, 66, 63, 204, 139, 64, 1229, 1, 4, 1, 222, 899, 28, 68, 4, 1, 9, 693, 2, 64, 1530, 50, 9, 215, 1, 386, 7, 59, 3, 1470, 798, 5, 176, 1, 391, 9, 1235, 29, 308, 3, 352, 343, 142, 129, 5, 27, 4, 125, 1470, 5, 308, 9, 532, 11, 107, 1466, 4, 57, 554, 100, 11, 308, 6, 226, 47, 3, 11, 8, 214]

# %% [markdown]
# # 讓轉換後的數字長度相同

# %% [markdown]
# # 文章內的文字，轉換為數字後，每一篇的文章地所產生的數字長度都不同，因為後需要進行類神經網路的訓練，所以每一篇文章所產生的數字長度必須相同
# # 以下列程式碼為例maxlen=100，所以每一篇文章轉換為數字都必須為100

# %%
x_train = sequence.pad_sequences(x_train_seq, maxlen=100)
x_test  = sequence.pad_sequences(x_test_seq,  maxlen=100)

# %% [markdown]
# # 如果文章轉成數字大於0,pad_sequences處理後，會truncate前面的數字

# %%
print('before pad_sequences length=',len(x_train_seq[0]))
print(x_train_seq[0])
# Out:
# before pad_sequences length= 106
# [308, 6, 3, 1068, 208, 8, 29, 1, 168, 54, 13, 45, 81, 40, 391, 109, 137, 13, 57, 149, 7, 1, 481, 68, 5, 260, 11, 6, 72, 5, 631, 70, 6, 1, 5, 1, 1530, 33, 66, 63, 204, 139, 64, 1229, 1, 4, 1, 222, 899, 28, 68, 4, 1, 9, 693, 2, 64, 1530, 50, 9, 215, 1, 386, 7, 59, 3, 1470, 798, 5, 176, 1, 391, 9, 1235, 29, 308, 3, 352, 343, 142, 129, 5, 27, 4, 125, 1470, 5, 308, 9, 532, 11, 107, 1466, 4, 57, 554, 100, 11, 308, 6, 226, 47, 3, 11, 8, 214]

# %%
print('after pad_sequences length=',len(x_train[0]))
print(x_train[0])
# Out:
# after pad_sequences length= 100
# [  29    1  168   54   13   45   81   40  391  109  137   13   57  149
#     7    1  481   68    5  260   11    6   72    5  631   70    6    1
#     5    1 1530   33   66   63  204  139   64 1229    1    4    1  222
#   899   28   68    4    1    9  693    2   64 1530   50    9  215    1
#   386    7   59    3 1470  798    5  176    1  391    9 1235   29  308
#     3  352  343  142  129    5   27    4  125 1470    5  308    9  532
#    11  107 1466    4   57  554  100   11  308    6  226   47    3   11
#     8  214]

# %% [markdown]
# # 如果文章轉成數字不足100,pad_sequences處理後，前面會加上0

# %%
print('before pad_sequences length=',len(x_train_seq[1]))
print(x_train_seq[1])
# Out:
# before pad_sequences length= 335
# [38, 13, 739, 43, 73, 31, 1828, 14, 149, 17, 111, 3, 1338, 5, 335, 144, 19, 1, 886, 11, 67, 276, 1190, 402, 33, 118, 282, 35, 166, 5, 391, 153, 38, 14, 1, 546, 87, 80, 100, 4, 1, 13, 39, 3, 412, 1199, 133, 40, 179, 137, 13, 1, 321, 19, 358, 5, 1, 38, 44, 25, 371, 5, 126, 52, 19, 1, 1980, 17, 47, 44, 21, 67, 344, 3, 5, 408, 19, 1, 1980, 14, 3, 205, 1, 21, 276, 65, 35, 3, 340, 1, 719, 725, 3, 1264, 19, 1, 1506, 3, 1220, 2, 282, 21, 276, 5, 63, 47, 41, 36, 5, 25, 11, 6, 33, 33, 379, 13, 294, 3, 1022, 128, 33, 43, 282, 7, 1, 178, 362, 5, 93, 3, 15, 3, 5, 63, 44, 26, 66, 408, 7, 1, 1980, 14, 499, 205, 1, 44, 26, 66, 78, 47, 26, 490, 15, 3, 701, 1181, 4, 227, 49, 1, 19, 117, 6, 1367, 19, 1, 886, 15, 3, 19, 23, 5, 23, 171, 843, 117, 26, 187, 1483, 121, 1, 236, 344, 1, 30, 3, 99, 41, 394, 19, 23, 117, 888, 81, 101, 582, 3, 251, 30, 1, 399, 4, 1956, 31, 1230, 33, 184, 154, 37, 340, 2, 37, 2, 33, 22, 454, 338, 5, 1, 1980, 502, 214, 236, 20, 338, 5, 36, 26, 276, 118, 50, 108, 1022, 117, 41, 544, 38, 511, 38, 25, 551, 133, 1, 115, 196, 2, 281, 1660, 5, 110, 9, 254, 109, 5, 25, 27, 4, 104, 117, 5, 108, 3, 208, 8, 283, 3, 495, 1074, 5, 23, 153, 137, 13, 181, 38, 14, 1, 546, 5, 119, 47, 41, 36, 256, 138, 154, 8, 1, 371, 247, 38, 19, 1, 81, 503, 227, 3, 374, 36, 28, 1022, 80, 78, 50, 32, 88, 120, 47, 5, 78, 15, 64, 274, 275, 32, 140, 198, 8, 5, 1, 300, 4, 767, 8, 36, 274, 38, 275, 10, 18, 76, 21, 5, 335, 404]

# %%
print('after pad_sequences length=',len(x_train[1]))
print(x_train[1])
# Out:
# after pad_sequences length= 100
# [ 544   38  511   38   25  551  133    1  115  196    2  281 1660    5
#   110    9  254  109    5   25   27    4  104  117    5  108    3  208
#     8  283    3  495 1074    5   23  153  137   13  181   38   14    1
#   546    5  119   47   41   36  256  138  154    8    1  371  247   38
#    19    1   81  503  227    3  374   36   28 1022   80   78   50   32
#    88  120   47    5   78   15   64  274  275   32  140  198    8    5
#     1  300    4  767    8   36  274   38  275   10   18   76   21    5
#   335  404]

# %% [markdown]
# # 資料預處理

# %%
token = Tokenizer(num_words=2000)
token.fit_on_texts(train_text)

# %%
x_train_seq = token.texts_to_sequences(train_text)
x_test_seq  = token.texts_to_sequences(test_text)

# %%
x_train = sequence.pad_sequences(x_train_seq, maxlen=100)
x_test  = sequence.pad_sequences(x_test_seq,  maxlen=100)
